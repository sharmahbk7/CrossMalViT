# %% [markdown]
# # Evaluation Analysis
#
# Compute metrics on synthetic predictions.

# %%
import numpy as np
from crossmal_vit.evaluation import compute_metrics

np.random.seed(0)
y_true = np.random.randint(0, 3, size=20)
y_pred = np.random.randint(0, 3, size=20)
metrics = compute_metrics(y_pred, y_true)
print(metrics)
