# %% [markdown]
# # Data Exploration
#
# Inspect class distribution and image shapes.

# %%
from pathlib import Path
import pandas as pd

root = Path('../data')
train_csv = root / 'train.csv'
if train_csv.exists():
    df = pd.read_csv(train_csv)
    print(df['label'].value_counts().head())
else:
    print('train.csv not found. Place dataset under ../data')
